# %% [markdown]
# 📊 🔑 Key Insights Summary (POC Level)
# 1. 📈 Trend Identification
# Several stocks show clear directional trends based on EMA/SMA.
# EMA-based signals react faster, helping capture short-term momentum.
#
# 👉 Insight:
# Stocks consistently trading above EMA indicate sustained bullish momentum, while flat trends suggest low opportunity phases.
#
# 2. 🎯 Entry & Exit Signals
# EMA crossover generates buy/sell signals.
# Clean crossovers align with strong trends; noisy crossovers indicate sideways markets.
#
# 👉 Insight:
# Signals are more reliable during trending periods and less effective in choppy conditions.
#
# 3. 📉 Risk Analysis (Volatility)
# Volatility varies significantly across stocks.
# Some stocks exhibit frequent spikes, indicating higher risk.
#
# 👉 Insight:
#
# High volatility = higher return potential but higher risk
# Low volatility = stable but slower growth
# 4. 🔗 Correlation & Diversification
# Many stocks show positive correlation (move together).
# Few pairs show lower correlation, useful for diversification.
#
# 👉 Insight:
# A portfolio of highly correlated stocks increases risk.
# Diversification requires mixing low-correlation stocks.
#
# 5. 📊 Performance Comparison
# Normalized charts reveal relative performance differences.
# Some stocks consistently outperform others over time.
#
# 👉 Insight:
# Top performers show strong trend + controlled volatility.
#
# 6. 📦 Volume Confirmation
# Price moves supported by high volume are more reliable.
# Low-volume movements are often weak or temporary.
#
# 👉 Insight:
# Volume helps validate trend strength.
#
# 🧠 Final Combined Insight (MOST IMPORTANT)
#
# “Trend + Risk + Correlation together provide a more complete decision framework.”
#
# ✅ Strong Opportunity
# Uptrend (EMA support)
# Controlled volatility
# Volume confirmation
# Low correlation with other holdings
# ⚠️ Risky Scenario
# High volatility spikes
# Frequent signal reversals
# High correlation across portfolio
